# %%
import pandas as pd

# %%
reporte=pd.read_csv("C:/Users/emolc/Documents/SEMANA 4 ENERO (INYECCION).csv")
reporte
# Out:
#       NOMBRE           FECHA_HORA  TURNO             CABIDADES_MOLDE  \
# 0      MARCO  2025-02-01 00:00:00      1  TOBERA CORTA 3/4 (6juegos)
# 1     DANIEL  2025-02-01 00:00:00      1                  TAPA 3 1/2
# 2    ANTONIO  2025-02-01 00:00:00      1       CUERPO 5 1/2 M.GRANDE
# 3     DANIEL  2025-01-31 00:00:00      1                CUERPO 4 1/2
# 4     DANIEL  2025-01-31 00:00:00      1            TAPA PLANA 4 1/2
# 5      DIEGO  2025-01-31 00:00:00      2            TAPA PLANA 4 1/2
# 6     BRAYAN  2025-01-31 00:00:00      2       CUERPO 5 1/2 M.GRANDE
# 7    ANTONIO  2025-01-31 00:00:00      1       CUERPO 5 1/2 M.GRANDE
# 8    BRANDON  2025-01-31 00:00:00      2  TOBERA CORTA 3/4 (6juegos)
# 9      MARCO  2025-01-31 00:00:00      1  TOBERA CORTA 3/4 (6juegos)
# 10    DANIEL  2025-01-30 00:00:00      1                CUERPO 4 1/2
# 11     DIEGO  2025-01-30 00:00:00      2                CUERPO 4 1/2
# 12  GILBERTO  2025-01-30 00:00:00      1       CUERPO 5 1/2 M.GRANDE
# ...

# %%
excel_reporte = reporte.to_excel("C:/Users/emolc/Documents/Reporte.xlsx", index=False)
